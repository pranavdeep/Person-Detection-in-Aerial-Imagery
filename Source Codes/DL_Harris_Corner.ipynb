# %%
pip install opencv_python opencv-contrib-python
# Out:
# Requirement already satisfied: opencv_python in /usr/local/lib/python3.7/dist-packages (3.4.2.17)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.7/dist-packages (3.4.2.17)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv_python) (1.19.5)

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/Sem-2/DL/Project - Person Detection/Heridal/heridal/patches/positive/pos1.jpg')
# convert to greyscale

gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)
# create SIFT feature extractor
dst = cv2.cornerHarris(gray, 2, 3, 0.04)
dst = cv2.dilate(dst,None)
plt.imshow(dst, cmap='gray')

# %%
image_copy = np.copy(img)

thresh = 0.05*dst.max()
corner_image = np.copy(image_copy)
for j in range(0, dst.shape[0]):
    for i in range(0, dst.shape[1]):
        if(dst[j,i] > thresh):
            # image, center pt, radius, color, thickness
            cv2.circle( corner_image, (i, j), 1, (0,255,0), 1)

plt.imshow(corner_image)

# %%
plt.imshow(dst)

# %%
# Out:
# numpy.ndarray

# %%
originalImage = np.copy(img)
flipVertical = cv2.flip(originalImage, 0)
flipHorizontal = cv2.flip(originalImage, 1)
flipBoth = cv2.flip(originalImage, -1)
 
#cv2_imshow(originalImage)
#cv2_imshow(flipVertical)
cv2_imshow(flipHorizontal)
#cv2_imshow(flipBoth)
# Out:
# <PIL.Image.Image image mode=RGB size=81x81 at 0x7F6D9BD5DD50>

# %%
corners = cv2.goodFeaturesToTrack(gray, 10, 0.0001, 10)
  
# convert corners values to integer
# So that we will be able to draw circles on them
corners = np.int0(corners)
  
# draw red color circles on all corners
for i in corners:
    x, y = i.ravel()
    cv2.circle(img, (x, y), 3, (255, 0, 0), -1)
  
# resulting image
plt.imshow(img)
